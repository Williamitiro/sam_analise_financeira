# %% [markdown]
# # 🚀 SAM - Análise Financeira & Growth (V7.1 Gold Standard)
#
# ---
#
# ### 📌 Como usar este Notebook (A Resposta para "Como Atualizar")
# Este notebook opera na **Arquitetura V7**.
# - **Toda a inteligência** está nos arquivos `.py` na pasta `celulas/`.
# - **Este notebook** é apenas o **Painel de Controle**.
# - **Para atualizar:** Basta rodar as células de novo! O comando `%autoreload 2` garante que qualquer alteração que eu faça nos arquivos `.py` seja carregada aqui **automaticamente**.
#
# ---

# %%
# 1. CONFIGURAÇÃO DE ATUALIZAÇÃO AUTOMÁTICA (O Segredo)
# %load_ext autoreload
# %autoreload 2
# Isso garante que alterações nos arquivos .py sejam carregadas instantaneamente aqui.

# %%
# 2. IMPORTAR O ORQUESTRADOR
import sys
import os

# Adiciona pasta de células ao path
sys.path.append(os.path.abspath('celulas'))

# Importa o criador do relatório
from loader_dados_relatorio import main
print("✅ Orquestrador carregado com sucesso!")
# Out:
# ⚠️  celula_0_utils não encontrado. Definindo helpers locais...
# ✅ Orquestrador carregado com sucesso!

# %% [markdown]
# ## 📊 MODO 1: Painel Interativo (Notebook)
# Use este modo para analisar os dados aqui na tela, com tabelas HTML ricas e logs detalhados.

# %%
# Rodar em modo interativo (HTML rico, Logs visíveis)
main(report_mode=False, run_monte_carlo=False)
# Out:
# ...
# 🚀 ORQUESTADOR DE RELATÓRIO - INICIANDO GERAÇÃO
#    Modo Relatório: False
#    Monte Carlo: False
# ...
#
# 📦 1. PREMISSAS CARREGADAS
#
# ⚙️  2. EXECUTANDO CENÁRIO REAL...
# ...
# 🚀 INICIANDO SIMULAÇÃO DO CENÁRIO REAL (BOOTSTRAP)
# ...
# 📅 Período: 36 meses (3 anos)
# 💰 Budget Marketing: R$ 1,500.00/mês
# 👥 Base Inicial: 5 usuários pagantes
# --------------------------------------------------------------------------------
#
# 📐 Gerando granularidades semanal e diária...
#    ✅ df_real_s: 25 semanas geradas
#    ✅ df_real_d: 180 dias gerados
#
# ...
# ✅ SIMULAÇÃO REAL CONCLUÍDA em 0.53s
# ...
#    ✅ Cenário Real concluído.
#
# ⚙️  3. EXECUTANDO CENÁRIO IDEAL...
#
# ...
# 🚀 INICIANDO CENÁRIO 05B — IDEAL (BENCHMARK-DRIVEN) — VERSÃO CORRIGIDA
# ...
#
# 🔧 Variáveis de cenário (variacao_params) preparadas.
#
# ⏱️ Rodando o motor financeiro com overrides do cenário ideal...
#
# ✔️ Motor concluído (tempo: 0.09s).
#
# 📐 Gerando granularidades semanal e diária para cenário IDEAL...
#    ✅ df_ideal_s: 25 semanas geradas
# ...

# %% [markdown]
# ## 📄 MODO 2: Gerar Relatório PDF (Gold Standard)
# Use este modo para ver exatamente o que vai para o PDF (Markdown limpo, Callouts, Sem logs).

# %%
# Rodar em modo PDF (Markdown limpo, Callouts, Sem Logs)
main(report_mode=True, run_monte_carlo=False)
# Out:
# ...
# 🚀 ORQUESTADOR DE RELATÓRIO - INICIANDO GERAÇÃO
#    Modo Relatório: True
#    Monte Carlo: False
# ...
#
# 📦 1. PREMISSAS CARREGADAS
#
# ⚙️  2. EXECUTANDO CENÁRIO REAL...
# ...
# 🚀 INICIANDO SIMULAÇÃO DO CENÁRIO REAL (BOOTSTRAP)
# ...
# 📅 Período: 36 meses (3 anos)
# 💰 Budget Marketing: R$ 1,500.00/mês
# 👥 Base Inicial: 5 usuários pagantes
# --------------------------------------------------------------------------------
#
# 📐 Gerando granularidades semanal e diária...
#    ✅ df_real_s: 25 semanas geradas
#    ✅ df_real_d: 180 dias gerados
#
# ...
# ✅ SIMULAÇÃO REAL CONCLUÍDA em 0.67s
# ...
#    ✅ Cenário Real concluído.
#
# ⚙️  3. EXECUTANDO CENÁRIO IDEAL...
#
# ...
# 🚀 INICIANDO CENÁRIO 05B — IDEAL (BENCHMARK-DRIVEN) — VERSÃO CORRIGIDA
# ...
#
# 🔧 Variáveis de cenário (variacao_params) preparadas.
#
# ⏱️ Rodando o motor financeiro com overrides do cenário ideal...
#
# ✔️ Motor concluído (tempo: 0.09s).
#
# 📐 Gerando granularidades semanal e diária para cenário IDEAL...
#    ✅ df_ideal_s: 25 semanas geradas
# ...
