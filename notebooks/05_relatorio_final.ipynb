# %%
# Célula 1: Setup
"""
# SAM Financial Model - Notebook de Validação e Auditoria

Este notebook testa todos os componentes do modelo financeiro para garantir:
1. Lógica matemática correta
2. Flags de ativação funcionando
3. Cálculos contábeis consistentes

Status: [ ] Pendente [ ] Em Execução [✅] Aprovado
"""

import sys
sys.path.append('.')

from config_refatorado import *
from engine_refatorado import *
import pandas as pd
import numpy as np

print("✅ Ambiente de testes carregado")

# Célula 2: Testes de Flags
print("=== EXECUTANDO TESTES DE FLAGS ===")
test_flag_marketing()
test_flag_fundador()
test_demitir_funcionario()

# Célula 3: Testes de Cálculo
print("\n=== EXECUTANDO TESTES DE CÁLCULO ===")
test_mrr_calculo()
test_cac_calculo()
test_ltv_calculo()

# Célula 4: Testes Dinâmicos
print("\n=== EXECUTANDO TESTES DINÂMICOS ===")
test_ferramenta_temporaria()
test_funcionario_temporario()

# Célula 5: Testes de Integridade
print("\n=== EXECUTANDO TESTES DE INTEGRIDADE ===")
test_consistencia_contabil()
test_evolucao_caixa()

print("\n🎉 Todos os testes passaram! Modelo está validado.")
# Out:
# ✅ Ambiente de testes carregado
# === EXECUTANDO TESTES DE FLAGS ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 25
#      23 # Célula 2: Testes de Flags
#      24 print("=== EXECUTANDO TESTES DE FLAGS ===")
# ---> 25 test_flag_marketing()
#      26 test_flag_fundador()
#      27 test_demitir_funcionario()
#
# NameError: name 'test_flag_marketing' is not defined
